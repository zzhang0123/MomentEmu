# %%
from MomentEmu.PolyEmu import PolyEmu
import numpy as np

# %%
# print the path to verify the correct module is imported
import MomentEmu
import os
print("Using MomentEmu from:", os.path.dirname(os.path.abspath(MomentEmu.__file__)))
# Out:
# Using MomentEmu from: /Users/zzhang/Workspace/MomentEmu/src/MomentEmu

# %%
np.random.seed(0)
X_train = np.random.uniform(1, 2, (500, 2))
Y_train1 = (X_train[:, 0]**2 + X_train[:, 1]**2).reshape(-1, 1)
Y_train2 = (X_train[:, 0]**3 + X_train[:, 1]).reshape(-1, 1)
Y_train = np.hstack((Y_train1, Y_train2))
X_train.shape
# Out:
# (500, 2)

# %%
emulator = PolyEmu(X_train, Y_train, forward=True, 
                   backward=False, 
                   standardize_Y_with_std=False)
# Out:
# Generating forward emulator...
# Set max_degree_forward to 31. Otherwise, a higher degree will require more samples.
# Forward emulator generated with degree 3, RMSE_val of 3.152497313193133e-15.
# Performing dimension reduction...
# Dimension reduced  from 10 modes to 6 modes.
# After the dimension reduction, the RMSE: 2.8759948205136916e-15, AIC: -33470.37775598755, BIC: -33445.090107397016

# %%
emulator.generate_forward_symb_emu()
# Out:
# [-1.88958754265911e-13*x1**3 + 1.00000000000085*x1**2 - 1.24357791904729e-12*x1 + 1.0*x2**2 + 5.88624134177712e-13,
#  0.999999999999945*x1**3 + 2.43360886997834e-13*x1**2 - 3.49942297361849e-13*x1 + 9.12963772248947e-16*x2**2 + 0.999999999999996*x2 + 1.65645275274073e-13]
